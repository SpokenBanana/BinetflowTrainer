# %% [markdown]
# Split into: train, test
#
# | File |      0       |     1
# |--------------|------------
# | capture20110810.binetflow |66527, 66471 |6887, 6943
# | capture20110811.binetflow |44985, 44928 |4501, 4558
# | capture20110812.binetflow |531250, 530994|12510, 12766
# | capture20110815.binetflow |49092, 49059 |742, 776
# | capture20110815-2.binetflow |5558, 5560 |400, 399
# | capture20110816.binetflow |24597, 24617 |488, 468
# | capture20110816-2.binetflow |4101, 4104 |15, 13
# | capture20110816-3.binetflow |215652, 215593|1405, 1465
# | capture20110817.binetflow |36800, 36992 |25329, 25138
# | capture20110818.binetflow |52505, 52470 |2149, 2184
# | capture20110818-2.binetflow |2675, 2710 |295, 260
# | capture20110819.binetflow |14040, 14058 |505, 487
# | capture20110815-3.binetflow |164998, 164784|16498, 16713

# %% [markdown]
# # WITH MASKED AND TUNED PARAMETERS
#
# ## File Accuracy for 0.15s
# |            File            |    Descision Tree    |    Random Forest     |      Tensorflow
# | ---------------------------|----------------------|----------------------|-----------------------
# | capture20110810.binetflow  |0.9935, 0.9675, 0.9634|0.9693, 0.9847, 0.6856|0.9685, 0.8814, 0.6416
# | capture20110811.binetflow  |0.9914, 0.9552, 0.9506|0.9653, 0.9804, 0.6358|0.9957, 0.9473, 0.9088
# | capture20110812.binetflow  |0.9994, 0.9907, 0.9828|0.9981, 0.9964, 0.9224|0.9989, 0.5146, 0.5071
# | capture20110815.binetflow  |0.9922, 0.7759, 0.7049|0.9870, 0.9388, 0.1778|0.9924, 0.2326, 0.2075
# | capture20110815-2.binetflow|0.9837, 0.8872, 0.8672|0.9560, 0.9660, 0.3559|0.9441, 0.3061, 0.1519
# | capture20110816.binetflow  |0.9944, 0.8776, 0.8120|0.9908, 0.9958, 0.5107|0.9927, 0.3086, 0.2794
# | capture20110816-2.binetflow|0.9925, 0.0909, 0.1538|0.9968, 0.0000, 0.0000|0.9968, 0.0000, 0.0000
# | capture20110816-3.binetflow|0.9990, 0.9419, 0.9078|0.9976, 0.9969, 0.6491|0.9933, 0.0000, 0.0000
# | capture20110817.binetflow  |0.9868, 0.9842, 0.9831|0.9625, 0.9629, 0.9438|0.9971, 0.9999, 0.9929
# | capture20110818.binetflow  |0.9918, 0.9148, 0.8755|0.9923, 0.9830, 0.8223|0.9968, 0.7025, 0.6921
# | capture20110818-2.binetflow|0.9721, 0.8583, 0.8154|0.9781, 0.9493, 0.7923|0.9788, 0.8267, 0.7321
# | capture20110819.binetflow  |0.9898, 0.8661, 0.8234|0.9746, 0.9535, 0.2526|0.9838, 0.4312, 0.3486
# | capture20110815-3.binetflow|0.9984, 0.9914, 0.9908|0.9918, 0.9956, 0.9147|0.9982, 0.9500, 0.9343
#
# ## File Accuracy for 0.25s
# |            File            |    Descision Tree    |    Random Forest     |      Tensorflow
# | ---------------------------|----------------------|----------------------|-----------------------
# | capture20110810.binetflow  |0.9746, 0.9175, 0.9046|0.9142, 0.9848, 0.4095|0.9274, 0.9012, 0.4879
# | capture20110811.binetflow  |0.9718, 0.8913, 0.8922|0.9095, 0.9624, 0.3174|0.9138, 0.7606, 0.3295
# | capture20110812.binetflow  |0.9978, 0.9693, 0.9584|0.9958, 0.9946, 0.8686|0.9996, 0.6270, 0.6244
# | capture20110815.binetflow  |0.9792, 0.5833, 0.5075|0.9767, 0.8718, 0.0465|0.9757, 0.0000, 0.0000
# | capture20110815-2.binetflow|0.9594, 0.8220, 0.7781|0.9091, 0.9796, 0.1283|0.8960, 0.0000, 0.0000
# | capture20110816.binetflow  |0.9785, 0.6812, 0.6124|0.9790, 0.9661, 0.3526|0.9826, 0.3871, 0.2996
# | capture20110816-2.binetflow|0.9915, 0.1111, 0.0714|0.9943, 0.0000, 0.0000|0.9943, 0.0000, 0.0000
# | capture20110816-3.binetflow|0.9970, 0.8798, 0.8252|0.9948, 0.9986, 0.4926|0.9964, 0.1972, 0.1874
# | capture20110817.binetflow  |0.9709, 0.9693, 0.9654|0.9345, 0.9511, 0.8992|0.9931, 0.9998, 0.9848
# | capture20110818.binetflow  |0.9862, 0.8519, 0.8369|0.9902, 0.9654, 0.8093|0.9932, 0.7131, 0.6631
# | capture20110818-2.binetflow|0.9630, 0.8222, 0.8132|0.9770, 0.9434, 0.8242|0.9742, 0.8492, 0.7924
# | capture20110819.binetflow  |0.9560, 0.6000, 0.5150|0.9515, 0.9762, 0.0880|0.9490, 0.0656, 0.0312

# %% [markdown]
# rf: n_trees = 50
# criteron = entropy
#
# dt: weighted
# citeron = entropy
#
#
# # File Accuracy for 0.15s
# |            File            |    Descision Tree    |    Random Forest     |      Tensorflow
# | ---------------------------|----------------------|----------------------|-----------------------
# | capture20110810.binetflow  |0.9859, 0.9266, 0.9240|0.9460, 0.9850, 0.4354|0.9564, 0.8124, 0.5186
# | capture20110811.binetflow  |0.9856, 0.9254, 0.9173|0.9435, 0.9752, 0.3964|0.9326, 0.5419, 0.2513
# | capture20110812.binetflow  |0.9984, 0.9729, 0.9567|0.9973, 0.9954, 0.8895|0.9907, 0.3651, 0.3203
# | capture20110815.binetflow  |0.9905, 0.7151, 0.6534|0.9862, 0.9681, 0.1173|0.9844, 0.0000, 0.0000
# | capture20110815-2.binetflow|0.9614, 0.7341, 0.6642|0.9450, 0.9610, 0.1855|0.9330, 0.0000, 0.0000
# | capture20110816.binetflow  |0.9892, 0.7391, 0.6538|0.9884, 0.9784, 0.3868|0.9875, 0.1811, 0.1489
# | capture20110816-2.binetflow|0.9917, 0.0000, 0.0000|0.9968, 0.0000, 0.0000|0.9968, 0.0000, 0.0000
# | capture20110816-3.binetflow|0.9983, 0.8969, 0.8375|0.9968, 0.9974, 0.5276|0.9933, 0.0000, 0.0000
# | capture20110817.binetflow  |0.9752, 0.9708, 0.9680|0.9417, 0.9468, 0.9069|0.9447, 0.9997, 0.8637
# | capture20110818.binetflow  |0.9910, 0.9156, 0.8539|0.9919, 0.9844, 0.8091|0.9885, 0.6097, 0.5431
# | capture20110818-2.binetflow|0.9710, 0.8537, 0.8077|0.9791, 0.9459, 0.8077|0.9788, 0.8429, 0.7194
# | capture20110819.binetflow  |0.9864, 0.8068, 0.7803|0.9722, 0.9556, 0.1766|0.9665, 0.0000, 0.0000
# | capture20110815-3.binetflow|0.9978, 0.9900, 0.9860|0.9866, 0.9969, 0.8568|0.9967, 0.9469, 0.9220
#
# # File Accuracy for 0.25s
# |            File            |    Descision Tree    |    Random Forest     |      Tensorflow
# |---------------------------|----------------------|----------------------|-----------------------
# | capture20110810.binetflow  |0.9565, 0.8629, 0.8290|0.8940, 0.9695, 0.2710|0.8860, 0.6218, 0.2044
# | capture20110811.binetflow  |0.9469, 0.7931, 0.8015|0.8996, 0.9422, 0.2442|0.8697, 0.0000, 0.0000
# | capture20110812.binetflow  |0.9968, 0.9526, 0.9442|0.9943, 0.9880, 0.8265|0.9968, 0.5894, 0.5657
# | capture20110815.binetflow  |0.9751, 0.4859, 0.4473|0.9763, 0.9048, 0.0260|0.9757, 0.0000, 0.0000
# | capture20110815-2.binetflow|0.8766, 0.4000, 0.3743|0.9008, 0.8148, 0.0588|0.8960, 0.0000, 0.0000
# | capture20110816.binetflow  |0.9715, 0.5617, 0.4784|0.9780, 0.9748, 0.3196|0.9759, 0.2293, 0.1566
# | capture20110816-2.binetflow|0.9883, 0.0000, 0.0000|0.9943, 0.0000, 0.0000|0.9943, 0.0000, 0.0000
# | capture20110816-3.binetflow|0.9957, 0.8125, 0.7576|0.9937, 1.0000, 0.3918|0.9897, 0.0000, 0.0000
# | capture20110817.binetflow  |0.9460, 0.9415, 0.9370|0.9274, 0.9407, 0.8934|0.9805, 0.9991, 0.9573
# | capture20110818.binetflow  |0.9837, 0.8068, 0.8329|0.9902, 0.9708, 0.8053|0.9875, 0.6607, 0.5768
# | capture20110818-2.binetflow|0.9641, 0.8138, 0.8407|0.9804, 0.9682, 0.8352|0.9692, 0.8898, 0.6624
# | capture20110819.binetflow  |0.9477, 0.5091, 0.4206|0.9499, 1.0000, 0.0558|0.9469, 0.0000, 0.0000
# | capture20110815-3.binetflow|0.9952, 0.9842, 0.9803|0.9735, 0.9904, 0.8145|0.9369, 0.9135, 0.5347
#
# # File Accuracy for 0.5s
# |            File             |     Descision Tree     |     Random Forest      | Tensorflow
# | --------------------------- | ---------------------- | ---------------------- | ---------:
# | capture20110810.binetflow   | 0.8526, 0.7038, 0.6897 | 0.8015, 0.7619, 0.2777 |     0.7599, 0.1591, 0.0213
# | capture20110811.binetflow   | 0.8565, 0.6613, 0.6354 | 0.8231, 0.7899, 0.2034 |     0.7947, 0.0819, 0.0123
# | capture20110812.binetflow   | 0.9841, 0.8585, 0.8195 | 0.9793, 0.9494, 0.6212 |     0.9866, 0.6963, 0.5903
# | capture20110815.binetflow   | 0.9283, 0.1721, 0.1546 | 0.9551, 0.6000, 0.0133 |     0.9549, 0.0000, 0.0000
# | capture20110815-2.binetflow | 0.7738, 0.3301, 0.3422 | 0.8355, 0.5229, 0.1894 |     0.8327, 0.0000, 0.0000
# | capture20110816.binetflow   | 0.9380, 0.4652, 0.3736 | 0.9528, 0.9490, 0.2081 |     0.9413, 0.0000, 0.0000
# | capture20110816-2.binetflow | 0.9822, 0.0000, 0.0000 | 0.9879, 0.0000, 0.0000 |     0.9879, 0.0000, 0.0000
# | capture20110816-3.binetflow | 0.9791, 0.4606, 0.3762 | 0.9831, 0.9848, 0.1417 |     0.9804, 0.0000, 0.0000
# | capture20110817.binetflow   | 0.9116, 0.9063, 0.9085 | 0.9122, 0.9422, 0.8691 |     0.9315, 0.9992, 0.8576
# | capture20110818.binetflow   | 0.9738, 0.7620, 0.7757 | 0.9829, 0.9646, 0.7217 |     0.9792, 0.6657, 0.5352
# | capture20110818-2.binetflow | 0.9395, 0.7475, 0.7184 | 0.9686, 0.9630, 0.7573 |     0.9507, 0.7848, 0.5324
# | capture20110819.binetflow   | 0.8547, 0.1853, 0.2091 | 0.9153, 0.5217, 0.0322 |     0.9151, 0.0000, 0.0000
# | capture20110815-3.binetflow | 0.9793, 0.9590, 0.9581 | 0.9103, 0.9511, 0.6759 |     0.9370, 0.9929, 0.7526
#
# # File Accuracy for 1s
# |            File             |     Descision Tree     |     Random Forest      | Tensorflow
# | --------------------------- | ---------------------- | ---------------------- | ---------:
# | capture20110810.binetflow   | 0.7058, 0.6289, 0.6326 | 0.6799, 0.6498, 0.4204 |     0.6019
# | capture20110811.binetflow   | 0.7349, 0.5811, 0.5694 | 0.7097, 0.5906, 0.2576 |     0.6826
# | capture20110812.binetflow   | 0.9537, 0.7444, 0.7060 | 0.9440, 0.8007, 0.4681 |     0.9145
# | capture20110815.binetflow   | 0.8868, 0.1806, 0.1717 | 0.9288, 0.3929, 0.0208 |     0.9279
# | capture20110815-2.binetflow | 0.7289, 0.5680, 0.4301 | 0.7300, 0.5935, 0.3382 |     0.7126
# | capture20110816.binetflow   | 0.8684, 0.3495, 0.4070 | 0.9136, 0.7386, 0.1752 |     0.8943
# | capture20110816-2.binetflow | 0.9694, 0.0000, 0.0000 | 0.9806, 0.0000, 0.0000 |     0.9814
# | capture20110816-3.binetflow | 0.9519, 0.3012, 0.2731 | 0.9664, 0.9079, 0.0559 |     0.9650
# | capture20110817.binetflow   | 0.8759, 0.8709, 0.8818 | 0.9014, 0.9462, 0.8506 |     0.6416
# | capture20110818.binetflow   | 0.9608, 0.6942, 0.7513 | 0.9784, 0.9620, 0.7093 |     0.9319
# | capture20110818-2.binetflow | 0.9507, 0.8235, 0.7636 | 0.9664, 0.9545, 0.7636 |     0.8688
# | capture20110819.binetflow   | 0.7987, 0.2073, 0.2028 | 0.8748, 0.6500, 0.0463 |     0.8670
# | capture20110815-3.binetflow | 0.8634, 0.8500, 0.8564 | 0.7563, 0.7814, 0.6581 |     0.5398
#
#
# # File Accuracy for 2s
# |            File             |     Descision Tree     |     Random Forest      | Tensorflow
# | --------------------------- | ---------------------- | ---------------------- | ---------:
# | capture20110810.binetflow   | 0.6408, 0.6625, 0.6548 | 0.6632, 0.6733, 0.7059 |     0.5380
# | capture20110811.binetflow   | 0.5852, 0.5361, 0.5322 | 0.6227, 0.6014, 0.4611 |     0.5535
# | capture20110812.binetflow   | 0.8866, 0.5767, 0.5613 | 0.9080, 0.7229, 0.5021 |     0.8665
# | capture20110815.binetflow   | 0.8105, 0.1667, 0.1542 | 0.8807, 0.3571, 0.0227 |     0.8864
# | capture20110815-2.binetflow | 0.7400, 0.6726, 0.7732 | 0.7889, 0.7368, 0.7938 |     0.5356
# | capture20110816.binetflow   | 0.7243, 0.3325, 0.3299 | 0.7946, 0.5283, 0.0711 |     0.7964
# | capture20110816-2.binetflow | 0.9452, 0.0909, 0.1250 | 0.9742, 0.0000, 0.0000 |     0.9710
# | capture20110816-3.binetflow | 0.8980, 0.1392, 0.1343 | 0.9416, 0.8974, 0.0333 |     0.9394
# | capture20110817.binetflow   | 0.8635, 0.8584, 0.8775 | 0.8909, 0.9424, 0.8376 |     0.6100
# | capture20110818.binetflow   | 0.9527, 0.7028, 0.6858 | 0.9719, 0.9417, 0.6828 |     0.9179
# | capture20110818-2.binetflow | 0.9286, 0.7317, 0.8571 | 0.9643, 0.9655, 0.8000 |     0.8501
# | capture20110819.binetflow   | 0.7049, 0.2764, 0.3178 | 0.7969, 0.3846, 0.0701 |     0.8078
# | capture20110815-3.binetflow | 0.7698, 0.8629, 0.8554 | 0.8152, 0.8345, 0.9666 |     0.8203
#
#
# # File Accuracy for 5s
# |            File             |     Descision Tree     |     Random Forest      | Tensorflow
# | --------------------------- | ---------------------- | ---------------------- | ---------:
# | capture20110810.binetflow   | 0.7322, 0.8236, 0.7943 | 0.8157, 0.8376, 0.9197 |     0.7127
# | capture20110811.binetflow   | 0.6642, 0.7325, 0.7531 | 0.7214, 0.7477, 0.8556 |     0.6553
# | capture20110812.binetflow   | 0.8723, 0.6825, 0.6594 | 0.9045, 0.8030, 0.6833 |     0.8040
# | capture20110815.binetflow   | 0.7415, 0.2921, 0.2806 | 0.8060, 0.4125, 0.1187 |     0.8166
# | capture20110815-2.binetflow | 0.7667, 0.7889, 0.7553 | 0.8111, 0.7885, 0.8723 |     0.5472
# | capture20110816.binetflow   | 0.5381, 0.5037, 0.5746 | 0.5669, 0.5439, 0.4366 |     0.5312
# | capture20110816-2.binetflow | 0.9355, 0.1429, 0.3333 | 0.9758, 0.0000, 0.0000 |     0.9516
# | capture20110816-3.binetflow | 0.7851, 0.1820, 0.1838 | 0.8683, 0.4500, 0.0295 |     0.8647
# | capture20110817.binetflow   | 0.8259, 0.8222, 0.8485 | 0.8897, 0.9263, 0.8557 |     0.5312
# | capture20110818.binetflow   | 0.9187, 0.6250, 0.6452 | 0.9505, 0.8864, 0.6290 |     0.8952
# | capture20110818-2.binetflow | 0.8667, 0.6154, 0.5333 | 0.9222, 1.0000, 0.5333 |     0.8212
# | capture20110819.binetflow   | 0.5955, 0.3234, 0.4538 | 0.6682, 0.3483, 0.2605 |     0.6803
# | capture20110815-3.binetflow | 0.9438, 0.9699, 0.9718 | 0.9671, 0.9698, 0.9968 |     0.9656

# %% [markdown]
# # For Bots
#
#
# # Bot accuracy for 0.15s
# |   Bot  |    Descision Tree    |    Random Forest     |      Tensorflow
# | -------|----------------------|----------------------|-----------------------
# | Menti  |0.9895, 0.7550, 0.6453|0.9880, 0.9826, 0.3611|0.9877, 0.1875, 0.1555
# | Murlo  |0.9982, 0.8930, 0.8375|0.9968, 0.9961, 0.5229|0.9933, 0.0000, 0.0000
# | NSIS.ay|0.9856, 0.7879, 0.7782|0.9720, 0.9762, 0.1684|0.9665, 0.0000, 0.0000
# | Virut  |0.9977, 0.9892, 0.9853|0.9872, 0.9956, 0.8622|0.9868, 0.9210, 0.8101
# | Sogou  |0.9939, 0.0000, 0.0000|0.9968, 0.0000, 0.0000|0.9968, 0.0000, 0.0000
# | Neris  |0.9856, 0.9671, 0.9602|0.9462, 0.9649, 0.7570|0.9723, 0.9983, 0.8607
# | Rbot   |0.9970, 0.9464, 0.9308|0.9962, 0.9925, 0.8513|0.9903, 0.3772, 0.3280
#
#
# # Bot accuracy for 0.25s
# |   Bot  |    Descision Tree    |    Random Forest     |      Tensorflow
# | -------|----------------------|----------------------|-----------------------
# | Menti  |0.9711, 0.5550, 0.4784|0.9780, 0.9747, 0.3175|0.9774, 0.2756, 0.1918
# | Murlo  |0.9958, 0.8200, 0.7611|0.9939, 0.9983, 0.4059|0.9897, 0.0000, 0.0000
# | NSIS.ay|0.9490, 0.5231, 0.4378|0.9492, 0.9545, 0.0451|0.9469, 0.0000, 0.0000
# | Virut  |0.9946, 0.9829, 0.9773|0.9731, 0.9935, 0.8080|0.8646, 0.5006, 0.9832
# | Sogou  |0.9879, 0.0000, 0.0000|0.9943, 0.0000, 0.0000|0.9943, 0.0000, 0.0000
# | Neris  |0.9590, 0.9203, 0.9094|0.9090, 0.9539, 0.6553|0.9546, 0.9991, 0.8137
# | Rbot   |0.9948, 0.9240, 0.9096|0.9935, 0.9909, 0.7997|0.9966, 0.5947, 0.5686
#
#
# # Bot accuracy for 0.5s
# |   Bot   |     Descision Tree     |     Random Forest      | Tensorflow
# | ------- | ---------------------- | ---------------------- | ---------:
# | NSIS.ay | 0.8556, 0.1713, 0.1823 | 0.9139, 0.3684, 0.0188 |     0.9129
# | Neris   | 0.8407, 0.7509, 0.7362 | 0.8380, 0.8887, 0.5526 |     0.6862
# | Murlo   | 0.9791, 0.4584, 0.3740 | 0.9831, 0.9848, 0.1424 |     0.9802
# | Menti   | 0.9365, 0.4524, 0.3826 | 0.9539, 0.9898, 0.2170 |     0.9423
# | Virut   | 0.9751, 0.9477, 0.9528 | 0.9018, 0.9442, 0.6444 |     0.7506
# | Sogou   | 0.9798, 0.0000, 0.0000 | 0.9879, 0.0000, 0.0000 |     0.9899
# | Rbot    | 0.9852, 0.8685, 0.8346 | 0.9795, 0.9755, 0.6116 |     0.9496
#
# # Bot accuracy for 1s
# |   Bot   |     Descision Tree     |     Random Forest      | Tensorflow
# | ------- | ---------------------- | ---------------------- | ---------:
# | NSIS.ay | 0.7974, 0.2192, 0.2278 | 0.8720, 0.5000, 0.0569 |     0.8670
# | Neris   | 0.7665, 0.7154, 0.7191 | 0.7758, 0.8276, 0.5756 |     0.5892
# | Murlo   | 0.9515, 0.2963, 0.2699 | 0.9666, 0.9722, 0.0567 |     0.9650
# | Menti   | 0.8721, 0.3571, 0.3908 | 0.9173, 0.8111, 0.1968 |     0.8943
# | Virut   | 0.9041, 0.8967, 0.8935 | 0.7601, 0.7891, 0.6500 |     0.5449
# | Sogou   | 0.9661, 0.0000, 0.0000 | 0.9806, 0.0000, 0.0000 |     0.9814
# | Rbot    | 0.9474, 0.6991, 0.6567 | 0.9471, 0.8379, 0.4591 |     0.9162
#
# # Bot accuracy for 2s
# |   Bot   |     Descision Tree     |     Random Forest      | Tensorflow
# | ------- | ---------------------- | ---------------------- | ---------:
# | NSIS.ay | 0.7158, 0.2689, 0.2664 | 0.7978, 0.4091, 0.0841 |     0.8078
# | Neris   | 0.6960, 0.6983, 0.7022 | 0.7319, 0.7654, 0.6775 |     0.6004
# | Murlo   | 0.9002, 0.1461, 0.1362 | 0.9407, 0.6829, 0.0267 |     0.9394
# | Menti   | 0.7379, 0.3600, 0.3426 | 0.8072, 0.7213, 0.1117 |     0.7964
# | Virut   | 0.7784, 0.8583, 0.8699 | 0.8137, 0.8313, 0.9660 |     0.8098
# | Sogou   | 0.9355, 0.0714, 0.1250 | 0.9742, 0.0000, 0.0000 |     0.9710
# | Rbot    | 0.8768, 0.5326, 0.5128 | 0.9093, 0.7529, 0.4611 |     0.8708
#
#
# # Bot accuracy for 5s
# |   Bot   |     Descision Tree     |     Random Forest      | Tensorflow
# | ------- | ---------------------- | ---------------------- | ---------:
# | NSIS.ay | 0.5955, 0.3370, 0.5126 | 0.6841, 0.3958, 0.3193 |     0.6803
# | Neris   | 0.7289, 0.7855, 0.7899 | 0.7897, 0.8082, 0.8781 |     0.6364
# | Murlo   | 0.7874, 0.1920, 0.1947 | 0.8661, 0.3220, 0.0208 |     0.8647
# | Menti   | 0.5394, 0.5052, 0.5493 | 0.5486, 0.5186, 0.4310 |     0.5312
# | Virut   | 0.9366, 0.9661, 0.9673 | 0.9605, 0.9653, 0.9941 |     0.9532
# | Sogou   | 0.9597, 0.2500, 0.3333 | 0.9758, 0.0000, 0.0000 |     0.9516
# | Rbot    | 0.8602, 0.6280, 0.6153 | 0.8983, 0.7879, 0.6230 |     0.8104

# %% [markdown]
# # Window Shifts
#
# # Window Shift Accuracy for 2s
# |            File             | Descision Tree | Random Forest
# | --------------------------- | -------------: | ------------:
# | capture20110810.binetflow   |         0.7409 |        0.6955
# | capture20110811.binetflow   |         0.7365 |        0.7230
# | capture20110812.binetflow   |         0.9218 |        0.9222
# | capture20110815.binetflow   |         0.8933 |        0.9000
# | capture20110815-2.binetflow |         0.7222 |        0.7778
# | capture20110816.binetflow   |         0.6579 |        0.7895
# | capture20110816-2.binetflow |         0.9167 |        1.0000
# | capture20110816-3.binetflow |         0.9097 |        0.9312
# | capture20110817.binetflow   |         0.9677 |        0.9677
# | capture20110818.binetflow   |         0.9645 |        0.9645
# | capture20110818-2.binetflow |         0.8750 |        1.0000
# | capture20110819.binetflow   |         0.7674 |        0.8605
# | capture20110815-3.binetflow |         0.7233 |        0.8081
#
# # Window Shift Accuracy for 5s
# |            File             | Descision Tree | Random Forest
# | --------------------------- | -------------: | ------------:
# | capture20110810.binetflow   |         0.8864 |        0.9205
# | capture20110811.binetflow   |         0.8475 |        0.8814
# | capture20110812.binetflow   |         0.9636 |        0.9750
# | capture20110815.binetflow   |         0.8500 |        0.8667
# | capture20110815-2.binetflow |         1.0000 |        1.0000
# | capture20110816.binetflow   |         0.6000 |        0.5667
# | capture20110816-2.binetflow |         1.0000 |        1.0000
# | capture20110816-3.binetflow |         0.7993 |        0.8710
# | capture20110817.binetflow   |         0.9730 |        1.0000
# | capture20110818.binetflow   |         0.9104 |        0.9254
# | capture20110818-2.binetflow |         1.0000 |        1.0000
# | capture20110819.binetflow   |         0.6471 |        0.5882
# | capture20110815-3.binetflow |         0.9617 |        0.9872
