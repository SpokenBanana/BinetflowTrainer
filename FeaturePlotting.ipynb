# %%
# %matplotlib inline

# %%
from utils import get_saved_data, get_feature_labels, get_binetflow_files
from stats import feature_plotting

binet_files = get_binetflow_files()

feature_plotting(1, binet_files[-1])
# Out:
# Using TensorFlow backend.

# %%
feature_plotting(3, binet_files[-1])

# %%
feature_plotting(18, binet_files[-1])

# %%
feature_plotting(3, binet_files[8])

# %%
feature_plotting(8, binet_files[8])

# %%
feature_plotting(8, binet_files[12])

# %%
feature_plotting(5, binet_files[12])
